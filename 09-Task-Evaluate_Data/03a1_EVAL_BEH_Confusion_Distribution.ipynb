# %% [markdown]
# # EVALUATION: Behavioral Snippet Categories Distributions

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from utils.utils import *

# %% [markdown]
# ## Prepare folder & files for results

# %% [markdown]
# ## Load data

# %%
# Snippet data
behavioral_data = pd.read_csv(get_behavioral_data_path(
    final_data_exclusion=True), sep=SEPARATOR, index_col=False, dtype={PARTICIPANT: str})
display(behavioral_data[CONDITION].value_counts())
# Out:
# Condition
# unambiguous    864
# ambiguous      863
# Name: count, dtype: int64

# %% [markdown]
# ## Overview over data:

# %%
ov, df_values = count_occurrences(behavioral_data, BEHAVIORAL_COLUMN_DURATION)
count_occurrences(behavioral_data, BEHAVIORAL_COLUMN_RATING)
# Out:
# (             Snippet_Rating
#  occurrences
#  11                        1
#  12                      143,
#          Snippet  count  occurrences
#  0     16-obf-v0     12           12
#  1    5-clean-v0     12           12
#  2     61-obf-v0     12           12
#  3       -obf-v0     12           12
#  4    8-clean-v0     12           12
#  ..          ...    ...          ...
#  139    8-obf-v1     12           12
#  140   11-obf-v1     12           12
#  141  5-clean-v1     12           12
#  142    9-obf-v1     12           12
#  143   62-obf-v0     11           11
#
#  [144 rows x 3 columns])

# %%
EVAL_PATH_AGGREGATED_DATA.mkdir(parents=True, exist_ok=True)
EVAL_PATH_AGGREGATED_DATA_SUMMARY.unlink(True)

# %% [markdown]
# ## Aggregate and contrast behavioral measures (clean / confusing)

# %%
group_factors = [SNIPPET, SNIPPET_COLUMN_NUMBER, SNIPPET_COLUMN_LANGHOUT_AOC_CATEGORY,
                 SNIPPET_COLUMN_AOC_CATEGORY, CONDITION]
# aggregate without skip factors in answers (to contrast answer time better)
answer_types = behavioral_data[BEHAVIORAL_COLUMN_ANSWER].unique()
display(answer_types)
behavioral_data_no_skips = behavioral_data[~behavioral_data[BEHAVIORAL_COLUMN_ANSWER].isna(
)]
answer_types = behavioral_data_no_skips[BEHAVIORAL_COLUMN_ANSWER].unique()
display(answer_types)
# Out:
# array(['3', 'false', '4', '5', '1', '2', nan, '7', 'true', '0', '10', '9',
#        '9.0', '50', '80', '62.0', '6', '40', '8', '42', '66', '27', '21',
#        '11', '60', '12', '13.0', '22', '256', '-1', '63.0', '20', '32',
#        '512', '24', '296', '288', '15', '13', '128', '255', '12.0',
#        'EMPTY', '500', '16'], dtype=object)
# array(['3', 'false', '4', '5', '1', '2', '7', 'true', '0', '10', '9',
#        '9.0', '50', '80', '62.0', '6', '40', '8', '42', '66', '27', '21',
#        '11', '60', '12', '13.0', '22', '256', '-1', '63.0', '20', '32',
#        '512', '24', '296', '288', '15', '13', '128', '255', '12.0',
#        'EMPTY', '500', '16'], dtype=object)

# %%
# aggregate measures per snippet level
behavioral_data_grouped1_all = group_aggregate_behavioral(behavioral_data, group_factors,
                                                          'snippet_level', display_df=False)
# without skip
behavioral_data_grouped_no_skips1_all = group_aggregate_behavioral(behavioral_data_no_skips, group_factors,
                                                                   'snippet_level_no_skips', display_df=False)
# Out:
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# ...

# %%
# aggregate measures per snippet number
behavioral_data_grouped2_all = group_aggregate_behavioral(
    behavioral_data, group_factors[1:], 'Number_level', display_df=False)
# without skip
behavioral_data_grouped_no_skips2_all = group_aggregate_behavioral(behavioral_data_no_skips, group_factors[1:],
                                                                   'Number_level_no_skips', display_df=False)
# Out:
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# ...

# %%
# aggregate measures per AoC level of Langhout
behavioral_data_grouped3_all = group_aggregate_behavioral(behavioral_data, group_factors[2:],
                                                          'Langhout_AoC_level', display_df=False)
# without skip
behavioral_data_grouped_no_skips3_all = group_aggregate_behavioral(behavioral_data_no_skips, group_factors[2:],
                                                                   'Langhout_AoC_no_skips', display_df=False)
# Out:
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# ...

# %%
# aggregate measures per our AoC level
behavioral_data_grouped4_all = group_aggregate_behavioral(
    behavioral_data, group_factors[3:], 'AoC_level', display_df=False)
# without skip
behavioral_data_grouped_no_skips4_all = group_aggregate_behavioral(behavioral_data_no_skips, group_factors[3:],
                                                                   'AoC_level_no_skips', display_df=False)
# Out:
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# Python\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1256: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# ...

# %%
# aggregate measures per condition
behavioral_data_grouped5_all = group_aggregate_behavioral(
    behavioral_data, group_factors[4:], 'cond_level', display_df=False)
# without skip
behavioral_data_grouped_no_skips5_all = group_aggregate_behavioral(
    behavioral_data_no_skips, group_factors[4:], 'cond_level_no_skips', plot_contrast_df=False)
# Out:
#      Condition  Duration_Min  Duration_Max  Duration_Mean  Duration_Std
# 0    ambiguous      3.049872     30.090370      12.038815      7.753948  \
# 1  unambiguous      3.080920     30.078748      10.960604      7.112054
#
#    Correctness_True  Correctness_False  Correctness_nan  Correctness_Rel_True
# 0               606                212                0              0.740831  \
# 1               764                 60                0              0.927184
#
#    Correctness_Rel_False  Correctness_Rel_nan  Rating_easy  Rating_hard
# 0               0.259169                    0          709           60  \
# 1               0.072816                    0          744           32
#
#    Rating_nan  Rating_Rel_easy  Rating_Rel_hard  Rating_Rel_nan
# 0           0         0.866748         0.073350               0
# 1           0         0.902913         0.038835               0
